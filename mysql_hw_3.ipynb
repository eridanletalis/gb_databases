# %% [markdown]
# <a href="https://colab.research.google.com/github/eridanletalis/gb_databases/blob/main/mysql_hw_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2>Урок 3. SQL – выборка данных, сортировка, агрегатные функции</h2>

# %% [markdown]
# 1. Отсортируйте данные по полю заработная плата (salary) в порядке: убывания; возрастания

# %% [markdown]
# <code>
# SELECT * <br />
# FROM staff <br />
# ORDER BY salary DESC;<br />
# </code>
# <br />
# <code>
# SELECT * <br />
# FROM staff<br />
# ORDER BY salary; -- Direct Order<br />
# </code>

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# 2. Выведите 5 максимальных заработных плат (saraly)

# %% [markdown]
# <code>
# -- DISTINCT для того, чтобы не выводить дубли, без него  будут выведены 100000 70000 70000 50000 30000 <br />
# SELECT DISTINCT salary<br />
# FROM staff<br />
# ORDER BY salary DESC<br />
# LIMIT 5; <br />
# </code>

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# 3. Посчитайте суммарную зарплату (salary) по каждой специальности (роst)

# %% [markdown]
# <code>
# SELECT post, sum(salary) sum_sal<br />
# FROM staff<br />
# GROUP BY post;<br />
# </code>

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# 4. Найдите кол-во сотрудников с специальностью (post) «Рабочий» в возрасте от 24 до 49 лет включительно.

# %% [markdown]
# <code>
# SELECT count(*) as young_cnt<br />
# FROM staff<br />
# WHERE post = 'Рабочий'<br />
# AND age BETWEEN 24 AND 49;<br />
# </code>

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# 5. Найдите количество специальностей

# %% [markdown]
# <code>
# SELECT count(distinct post) spec_cnt<br />
# FROM staff;<br />
# </code>

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# 6. Выведите специальности, у которых средний возраст сотрудников меньше 30 лет

# %% [markdown]
# <code>
# SELECT DISTINCT post<br />
# FROM staff<br />
# GROUP BY post<br />
# HAVING AVG(age) < 30.0;<br />
# </code>

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)
