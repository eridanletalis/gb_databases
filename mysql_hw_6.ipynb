# %% [markdown]
# <a href="https://colab.research.google.com/github/eridanletalis/gb_databases/blob/main/mysql_hw_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2>Урок 6. SQL – Транзакции. Временные таблицы, управляющие конструкции, циклы</h2>
#
# 1. Создайте таблицу users_old, аналогичную таблице users. Создайте процедуру, с
# помощью которой можно переместить любого (одного) пользователя из таблицы
# users в таблицу users_old. (использование транзакции с выбором commit или rollback – обязательно).

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# 2. Создайте хранимую функцию hello(), которая будет возвращать приветствие, в
# зависимости от текущего времени суток. С 6:00 до 12:00 функция должна
# возвращать фразу "Доброе утро", с 12:00 до 18:00 функция должна возвращать
# фразу "Добрый день", с 18:00 до 00:00 — "Добрый вечер", с 00:00 до 6:00 — "Доброй ночи".

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# 3. (по желанию)* Создайте таблицу logs типа Archive. Пусть при каждом создании
# записи в таблицах users, communities и messages в таблицу logs помещается время и дата создания записи, название таблицы, идентификатор первичного ключа.
# Для решения задач используйте базу данных lesson_4
# (скрипт создания, прикреплен к 4 семинару).

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# Первые два - отладочные
#
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)
