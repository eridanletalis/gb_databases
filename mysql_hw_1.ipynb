# %% [markdown]
# <a href="https://colab.research.google.com/github/eridanletalis/gb_databases/blob/main/mysql_hw_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2>Задания</h2>
#
#
# 1.   Создайте таблицу с мобильными телефонами, используя графический интерфейс.Заполните БД данными. (см. презентацию)
#
# <code>CREATE TABLE 'lesson_1'.'phones' ( <br />
#   'id' INT NOT NULL AUTO_INCREMENT,<br />
#   'ProductName' VARCHAR(255) NOT NULL,<br />
#   'Manufactorer' VARCHAR(45) NOT NULL,<br />
#   'ProductCount' INT UNSIGNED NOT NULL,<br />
#   'Price' DECIMAL(10,2) UNSIGNED NOT NULL,<br />
#   PRIMARY KEY ('id'));<code><br />
#
# SQL script was successfully applied to the database.

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# 2.   Выведите название, производителя и цену для товаров, количество которых превышает 2.
#
# <code>
# SELECT *<br />
# FROM lesson_1.phones<br />
# WHERE ProductCount > 2;<br />
# </code>

# %% [markdown]
# 3.   Выведите весь ассортимент товаров марки “Samsung”.
#
# <code>
# SELECT * <br />
# FROM lesson_1.phones<br />
# WHERE Manufacorer = 'Samsung';<br />
# </code>

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# 4.   Выведите информацию о телефонах, где суммарный чек больше 100 000 и меньше 145 000.
# <code>
# SELECT * <br />
# FROM lesson_1.phones<br />
# WHERE ProductCount*Price BETWEEN 100000 AND 145000;<br />
# </code>

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# 5.   С помощью регулярных выражений найти (можно использовать операторы “LIKE”, “RLIKE для 5.3” ):
#
# *   Товары, в которых есть упоминание "Iphone".
#
#
# <strong>Без регулярок</strong><br />
# <code>
# SELECT * <br />
# FROM lesson_1.phones<br />
# WHERE ProductName LIKE '%Iphone%';<br />
# </code>
#
# <strong>C REGEX</strong><br />
# <code>
# SELECT * <br />
# FROM lesson_1.phones<br />
# WHERE  REGEXP_LIKE(ProductName, 'Iphone');<br />
# </code>

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# *   "Galaxy".
#
# Аналогично
#
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# Вариант, когда при поиске важен регистр
#
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# *   Товары, в которых есть ЦИФРЫ.

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# *   Товары, в которых есть ЦИФРА "8".
#
#
# ![изображение.png](data:image/png;base64,...)
